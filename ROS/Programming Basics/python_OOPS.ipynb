# %% [markdown]
# PYTHON: OBJECT ORIENTED PROGRAMMING

# %% [markdown]
# OBJECT : A "Bundle" of related attributes(variables) and meathods(function)
#
# CLASS : A "Blueprint" for creating objects. It defines a set of attributes and methods that the created objects will have.

# %%
class Car:
    def __init__(self, model, year, color, for_sale):
        self.model = model
        self.objectyear = year
        self.color = color
        self.for_sale = for_sale

Car1 = Car("Toyota Camry", 2020, "Red", True)
Car2 = Car("Honda Accord", 2019, "Blue", False)
Car3 = Car("Ford Mustang", 2021, "Black", True)
print(Car2) # Returns memoory address of the argument
print(Car1.color) #access values of the object
# Out:
# ...
# Red
